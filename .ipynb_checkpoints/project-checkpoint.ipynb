# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

#tb.loc[tb['Instrument Classification (ISO 10962 CFI code)'].isin(['JFTXFP'])]
#tb.plot.hist(tb.groupby(['Trading platform']).Price.agg(['mean', max]))
#tb.describe()
#print(tb.shape)

df = pd.read_csv('C:/Users/inald/Documents/NWMprod/wetransfer-0f4d76/rts27.csv')

#print(df.shape)
#df.head(20)
# Out:
#                 id        bank_name                       legal_entity_name  \
# 101       67771595   Morgan Stanley  Morgan Stanley & Co. International Plc
# 102       67771596   Morgan Stanley  Morgan Stanley & Co. International Plc
# 103       67771597   Morgan Stanley  Morgan Stanley & Co. International Plc
# 104       67771598   Morgan Stanley  Morgan Stanley & Co. International Plc
# 105       67771599   Morgan Stanley  Morgan Stanley & Co. International Plc
# ...            ...              ...                                     ...
# 12899305  29331807  Natwest Markets                     Natwest Markets PLC
# 12899307  29331809  Natwest Markets                     Natwest Markets PLC
# 12899308  29331810  Natwest Markets                     Natwest Markets PLC
# 12899310  29331812  Natwest Markets                     Natwest Markets PLC
# 12899311  29331813  Natwest Markets                     Natwest Markets PLC
#
#                                                   file_name  \
# 101                      mifid2_rts27_forwards_T1_T2_T6.csv
# 102                      mifid2_rts27_forwards_T1_T2_T6.csv
# 103                      mifid2_rts27_forwards_T1_T2_T6.csv
# 104                      mifid2_rts27_forwards_T1_T2_T6.csv
# 105                      mifid2_rts27_forwards_T1_T2_T6.csv
# ...                                                     ...
# 12899305  RTS27_Table6_LikelihoodOfExecution_20180401_20...
# 12899307  RTS27_Table6_LikelihoodOfExecution_20180401_20...
# 12899308  RTS27_Table6_LikelihoodOfExecution_20180401_20...
# 12899310  RTS27_Table6_LikelihoodOfExecution_20180401_20...
# 12899311  RTS27_Table6_LikelihoodOfExecution_20180401_20...
#
#           date_of_trading_day instrument_identifier instrument_classification  \
# 101       2018-09-28 00:00:00          EZ24NVRGSWM1                    JFTXFP
# 102       2018-09-06 00:00:00                   NaN                    JFTXFP
# 103       2018-07-13 00:00:00          EZ6HV8SZ0GB1                    JFTXFP
# 104       2018-08-31 00:00:00                   NaN                    JFTXFP
# 105       2018-07-20 00:00:00          EZW2B7BGWGS3                    JFTXFP
# ...                       ...                   ...                       ...
# 12899305  2018-04-16 00:00:00          EZV9F8FK9N90                    JFTXFP
# 12899307  2018-04-16 00:00:00          EZVB0FHV4HR5                    JFTXFP
# 12899308  2018-04-16 00:00:00          EZVB0H00LCW1                    JFTXFP
# 12899310  2018-04-16 00:00:00          EZVB63CGLBZ7                    JFTXFP
# 12899311  2018-04-16 00:00:00          EZVB826LVWC0                    JFTXFP
#
#           order_request_quotes_received  executed_transactions  \
# 101                                 0.0                    NaN
# 102                                 1.0                    NaN
# 103                                 1.0                    NaN
# 104                                 1.0                    NaN
# 105                                 1.0                    NaN
# ...                                 ...                    ...
# 12899305                            1.0                    NaN
# 12899307                            1.0                    NaN
# 12899308                            3.0                    2.0
# 12899310                            5.0                    NaN
# 12899311                            1.0                    NaN
#
#           total_value_of_transactions  ...  median_transaction_size_eur  \
# 101                               NaN  ...                          NaN
# 102                               NaN  ...                          NaN
# 103                               NaN  ...                          NaN
# 104                               NaN  ...                          NaN
# 105                               NaN  ...                          NaN
# ...                               ...  ...                          ...
# 12899305                          NaN  ...                          NaN
# 12899307                          NaN  ...                          NaN
# 12899308                   1972353.34  ...                    986176.67
# 12899310                          NaN  ...                          NaN
# 12899311                          NaN  ...                          NaN
#
#           median_transaction_size_gbp  median_size_request_quotes_eur  \
# 101                               NaN                             NaN
# 102                               NaN                             NaN
# 103                               NaN                             NaN
# 104                               NaN                             NaN
# 105                               NaN                             NaN
# ...                               ...                             ...
# 12899305                          NaN                    5.000000e+05
# 12899307                          NaN                    1.190622e+07
# 12899308                          NaN                    3.591434e+05
# 12899310                          NaN                    1.616815e+07
# 12899311                          NaN                    1.298312e+04
#
#           median_size_request_quotes_gbp  smartie_instrument_name  \
# 101                                  NaN                      NaN
# 102                                  NaN                      NaN
# 103                                  NaN                      NaN
# 104                                  NaN                      NaN
# 105                                  NaN                      NaN
# ...                                  ...                      ...
# 12899305                             NaN                      NaN
# 12899307                             NaN                      NaN
# 12899308                             NaN                      NaN
# 12899310                             NaN                      NaN
# 12899311                             NaN                      NaN
#
#          data_quality_flag egb_eligible_flag year_quarter business  \
# 101                    NaN               NaN      2018 Q3      NaN
# 102                    NaN               NaN      2018 Q3      NaN
# 103                    NaN               NaN      2018 Q3      NaN
# 104                    NaN               NaN      2018 Q3      NaN
# 105                    NaN               NaN      2018 Q3      NaN
# ...                    ...               ...          ...      ...
# 12899305               NaN               NaN      2018 Q2      NaN
# 12899307               NaN               NaN      2018 Q2      NaN
# 12899308               NaN               NaN      2018 Q2      NaN
# 12899310               NaN               NaN      2018 Q2      NaN
# 12899311               NaN               NaN      2018 Q2      NaN
#
#          central_bank_isin_flag
# 101                         NaN
# 102                         NaN
# 103                         NaN
# 104                         NaN
# 105                         NaN
# ...                         ...
# 12899305                    NaN
# 12899307                    NaN
# 12899308                    NaN
# 12899310                    NaN
# 12899311                    NaN
#
# [3649179 rows x 37 columns]

# %%
#Columns deemed unneccessary for this task
dfFiltered = df.drop(['file_name','designated_market_makers','legal_entity_name', 'systematic_internaliser_flag'], axis = 1)

#Filters the code to FX forwards only
dfFiltered = dfFiltered.loc[(df['instrument_classification']).astype(str).str.contains("JF")]

#Drops the columns of which half of the fields have no data.
dfFiltered = dfFiltered.dropna(axis=1, thresh=2000000)

dfFiltered
# Out:
#                 id        bank_name  date_of_trading_day  \
# 100       67771594   Morgan Stanley  2018-09-13 00:00:00
# 101       67771595   Morgan Stanley  2018-09-28 00:00:00
# 102       67771596   Morgan Stanley  2018-09-06 00:00:00
# 103       67771597   Morgan Stanley  2018-07-13 00:00:00
# 104       67771598   Morgan Stanley  2018-08-31 00:00:00
# ...            ...              ...                  ...
# 12899305  29331807  Natwest Markets  2018-04-16 00:00:00
# 12899307  29331809  Natwest Markets  2018-04-16 00:00:00
# 12899308  29331810  Natwest Markets  2018-04-16 00:00:00
# 12899310  29331812  Natwest Markets  2018-04-16 00:00:00
# 12899311  29331813  Natwest Markets  2018-04-16 00:00:00
#
#          instrument_identifier instrument_classification  \
# 100               EZ43HP8WC2Y3                    JFTXFC
# 101               EZ24NVRGSWM1                    JFTXFP
# 102                        NaN                    JFTXFP
# 103               EZ6HV8SZ0GB1                    JFTXFP
# 104                        NaN                    JFTXFP
# ...                        ...                       ...
# 12899305          EZV9F8FK9N90                    JFTXFP
# 12899307          EZVB0FHV4HR5                    JFTXFP
# 12899308          EZVB0H00LCW1                    JFTXFP
# 12899310          EZVB63CGLBZ7                    JFTXFP
# 12899311          EZVB826LVWC0                    JFTXFP
#
#           order_request_quotes_received  executed_transactions  \
# 100                                 0.0                    NaN
# 101                                 0.0                    NaN
# 102                                 1.0                    NaN
# 103                                 1.0                    NaN
# 104                                 1.0                    NaN
# ...                                 ...                    ...
# 12899305                            1.0                    NaN
# 12899307                            1.0                    NaN
# 12899308                            3.0                    2.0
# 12899310                            5.0                    NaN
# 12899311                            1.0                    NaN
#
#           order_request_quotes_can_wdrwn  order_request_quotes_modified  \
# 100                                  NaN                            NaN
# 101                                  NaN                            NaN
# 102                                  NaN                            NaN
# 103                                  NaN                            NaN
# 104                                  NaN                            NaN
# ...                                  ...                            ...
# 12899305                             1.0                            NaN
# 12899307                             1.0                            NaN
# 12899308                             1.0                            NaN
# 12899310                             4.0                            NaN
# 12899311                             1.0                            NaN
#
#           median_size_request_quotes active         date_created  \
# 100                              NaN      Y  2019-01-15 15:01:55
# 101                              NaN      Y  2019-01-15 15:01:55
# 102                              NaN      Y  2019-01-15 15:01:55
# 103                              NaN      Y  2019-01-15 15:01:55
# 104                              NaN      Y  2019-01-15 15:01:55
# ...                              ...    ...                  ...
# 12899305                5.000000e+05      Y  2019-01-03 11:50:47
# 12899307                1.190622e+07      Y  2019-01-03 11:50:47
# 12899308                3.591434e+05      Y  2019-01-03 11:50:47
# 12899310                1.616815e+07      Y  2019-01-03 11:50:47
# 12899311                1.298312e+04      Y  2019-01-03 11:50:47
#
#          source_instrument_ccy source_market_segment  \
# 100                    USD|BRL                   NaN
# 101                    USD|SEK                   NaN
# 102                    USD|TRY                   NaN
# 103                    USD|TRY                   NaN
# 104                    USD|DKK                   NaN
# ...                        ...                   ...
# 12899305               BHD,EUR                   NaN
# 12899307               NZD,USD                   NaN
# 12899308               EUR,USD                   NaN
# 12899310               GBP,USD                   NaN
# 12899311               EUR,RUB                   NaN
#
#          traded_in_natwest_markets source_instrument_name  \
# 100                            Yes                    NaN
# 101                            Yes                    NaN
# 102                             No                    NaN
# 103                            Yes                    NaN
# 104                             No                    NaN
# ...                            ...                    ...
# 12899305                       Yes                    NaN
# 12899307                       Yes                    NaN
# 12899308                       Yes                    NaN
# 12899310                       Yes                    NaN
# 12899311                       Yes                    NaN
#
#           median_size_request_quotes_eur  median_size_request_quotes_gbp  \
# 100                                  NaN                             NaN
# 101                                  NaN                             NaN
# 102                                  NaN                             NaN
# 103                                  NaN                             NaN
# 104                                  NaN                             NaN
# ...                                  ...                             ...
# 12899305                    5.000000e+05                             NaN
# 12899307                    1.190622e+07                             NaN
# 12899308                    3.591434e+05                             NaN
# 12899310                    1.616815e+07                             NaN
# 12899311                    1.298312e+04                             NaN
#
#          year_quarter
# 100           2018 Q3
# 101           2018 Q3
# 102           2018 Q3
# 103           2018 Q3
# 104           2018 Q3
# ...               ...
# 12899305      2018 Q2
# 12899307      2018 Q2
# 12899308      2018 Q2
# 12899310      2018 Q2
# 12899311      2018 Q2
#
# [4333659 rows x 19 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Select target
y = df['date_created']
# To keep things simple, we'll use only numerical predictors
predictors = df.drop(['date_created'], axis=1)
X = df

# Divide data into training and validation subsets
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,
                                                      random_state=0)

# %%
from sklearn.impute import SimpleImputer

# Imputation
my_imputer = SimpleImputer(missing_values='np.nan', strategy = 'most_frequent')
imputed_X_train = pd.DataFrame(my_imputer.fit_transform(X_train))
imputed_X_valid = pd.DataFrame(my_imputer.transform(X_valid))

# Imputation removed column names; put them back
imputed_X_train.columns = X_train.columns
imputed_X_valid.columns = X_valid.columns

print(imputed_X_train.columns.isnull().sum())
# Out:
# Categorical variables:
# ['bank_name', 'legal_entity_name', 'file_name', 'instrument_identifier', 'instrument_classification', 'active', 'source_instrument_desc', 'source_instrument_ccy', 'source_market_segment', 'smartie_instrument_id', 'systematic_internaliser_flag', 'liquidity_provider_flag', 'traded_in_natwest_markets', 'source_instrument_name', 'smartie_instrument_name', 'data_quality_flag', 'egb_eligible_flag', 'year_quarter', 'business', 'central_bank_isin_flag']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode(values, uniques, encode, check_unknown)
#     112         try:
# --> 113             res = _encode_python(values, uniques, encode)
#     114         except TypeError:
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode_python(values, uniques, encode)
#      60     if uniques is None:
# ---> 61         uniques = sorted(set(values))
#      62         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'NoneType' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-bd45293933c1> in <module>
#      15 label_encoder = LabelEncoder()
#      16 for col in object_cols:
# ---> 17     label_encoder.fit(pd.concat([X_train[col], X_valid[col]], axis=0, sort=False))
#      18     label_X_train[col] = label_encoder.transform(X_train[col])
#      19     label_X_valid[col] = label_encoder.transform(X_valid[col])
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in fit(self, y)
#     238         """
#     239         y = column_or_1d(y, warn=True)
# --> 240         self.classes_ = _encode(y)
#     241         return self
#     242
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode(values, uniques, encode, check_unknown)
#     115             types = sorted(t.__qualname__
#     116                            for t in set(type(v) for v in values))
# --> 117             raise TypeError("Encoders require their input to be uniformly "
#     118                             f"strings or numbers. Got {types}")
#     119         return res
#
# TypeError: Encoders require their input to be uniformly strings or numbers. Got ['NoneType', 'str']

# %%
from sklearn.preprocessing import LabelEncoder

# Get list of categorical variables
s = (X_train.dtypes == 'object')
object_cols = list(s[s].index)

print("Categorical variables:")
print(object_cols)

# Make copy to avoid changing original data 
label_X_train = X_train.copy()
label_X_valid = X_valid.copy()

# Apply label encoder to each column with categorical data
label_encoder = LabelEncoder()
for col in object_cols:
    label_encoder.fit(pd.concat([X_train[col], X_valid[col]], axis=0, sort=False))
    label_X_train[col] = label_encoder.transform(X_train[col])
    label_X_valid[col] = label_encoder.transform(X_valid[col])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-19-62b83c595b14> in <module>
#       2 df.dropna(axis=1, thresh=1000000)
#       3 df.drop(columns=['designated_market_makers','legal_entity_name', 'systematic_internaliser_flag'])
# ----> 4 pd.get_dummies(df)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     913         for (col, pre, sep) in zip(data_to_encode.items(), prefix, prefix_sep):
#     914             # col is (column_name, column), use just column data here
# --> 915             dummy = _get_dummies_1d(
#     916                 col[1],
#     917                 prefix=pre,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#    1033
#    1034     else:
# -> 1035         dummy_mat = np.eye(number_of_cols, dtype=dtype).take(codes, axis=0)
#    1036
#    1037         if not dummy_na:
#
# ~\anaconda3\lib\site-packages\numpy\lib\twodim_base.py in eye(N, M, k, dtype, order)
#     199     if M is None:
#     200         M = N
# --> 201     m = zeros((N, M), dtype=dtype, order=order)
#     202     if k >= M:
#     203         return m
#
# MemoryError: Unable to allocate 409. GiB for an array with shape (662704, 662704) and data type uint8

# %%
pd.get_dummies(df)
